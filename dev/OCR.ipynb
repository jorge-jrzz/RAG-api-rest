# %% [markdown]
# ## OCR with UNSTRUCTURED

# %% [markdown]
# Hacer las peticiones al `http://localhost:8000`
#
# Con el siguente comando se puede correr el contenedor de UNSTRUCTURED:
#
# ```bash
# docker run -p 8000:8000 -d --rm --name unstructured-api downloads.unstructured.io/unstructured-io/unstructured-api:latest --port 8000 --host 0.0.0.0
# ```
#
# *More info about the image here: ([UnstructuredLoader | 🦜️🔗 Langchain](https://js.langchain.com/v0.2/docs/integrations/document_loaders/file_loaders/unstructured/))*
#
# *More info aboaut the python SDK here: [Process an individual file by using the Unstructured Python SDK - Unstructured](https://docs.unstructured.io/api-reference/api-services/sdk-python)*

# %%
# Dependencies

# %pip install unstructured-client

# %%
import os
import json
import unstructured_client
from unstructured_client.models import operations, shared

client = unstructured_client.UnstructuredClient(
    server_url="http://localhost:8000",
)

filename = "file.pdf"
with open(filename, "rb") as f:
    data = f.read()

req = operations.PartitionRequest(
    partition_parameters=shared.PartitionParameters(
        files=shared.Files(
            content=data,
            file_name=filename,
        ),
        strategy=shared.Strategy.HI_RES,
        languages=['eng'],
        split_pdf_page=True,            # If True, splits the PDF file into smaller chunks of pages.
        split_pdf_allow_failed=True,    # If True, the partitioning continues even if some pages fail.
        split_pdf_concurrency_level=15  # Set the number of concurrent request to the maximum value: 15.
    ),
)

try:
    res = client.general.partition(request=req)
    element_dicts = [element for element in res.elements]
    json_elements = json.dumps(element_dicts, indent=2)

    # Print the processed data.
    print(json_elements)

    # Write the processed data to a local file.
    with open("salida.txt", "w") as file:
        file.write(json_elements)
except Exception as e:
    print(e)
# Out:
# INFO: Preparing to split document for partition.
# INFO: Starting page number set to 1
# INFO: Allow failed set to 1
# INFO: Concurrency level set to 15
# INFO: Splitting pages 1 to 2 (2 total)
# INFO: Determined optimal split size of 2 pages.
# INFO: Document has too few pages (2) to be split efficiently. Partitioning without split.
# INFO: Successfully partitioned the document.
# [
#   {
#     "type": "NarrativeText",
#     "element_id": "084bcfca09086336d78c8ba5c6103a13",
#     "text": "18. Cuando hablamos de capacitaci\u00f3n, tenemos como uno de los beneficios principales, la mejora de la calidad del Software \u00bfA qu\u00e9 nos referimos con esto?",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 1,
#       "filename": "file.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "f666bfbe7368828ec28fc42ca8724ce3",
#     "text": "a. A un c\u00f3digo bien documentado e indentado. b. A un c\u00f3digo con menos errores, mayor confiabilidad y que genera satisfacci\u00f3n al cliente. c. A un c\u00f3digo que sustituye \u201cifs\u201d por \u201cswitch\u201d para darle mejor presentaci\u00f3n. d. A un c\u00f3digo que utiliza patrones de dise\u00f1o para optimizarse a s\u00ed mismo. 19. \u00bfCu\u00e1l de las siguientes opciones abarca actividades relacionadas con la capacitaci\u00f3n en el contexto de la gesti\u00f3n de la calidad del software seg\u00fan el est\u00e1ndar IEEE-730?",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 1,
#       "filename": "file.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "4332441c8e57be5ef5b613fa622bdf5c",
#     "text": "a. Entrenamiento en herramientas y tecnolog\u00edas. b. Formaci\u00f3n en metodolog\u00edas y procesos. c. Cumplimiento de est\u00e1ndares y regulaciones. d. Todas las anteriores.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 1,
#       "filename": "file.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "ae309bf390a880f478d767747f9d71b9",
#     "text": "20. \u00bfCu\u00e1l es uno de los resultados esperados de las mediciones del proceso de software seg\u00fan el est\u00e1ndar IEEE 730-2002?",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 1,
#       "filename": "file.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "e9d34c7b022c6f34f3fbb498b28f7cbc",
#     "text": "a. Asegurar la conformidad con los est\u00e1ndares de dise\u00f1o. b. Documentar los requisitos del software. c. Representar con precisi\u00f3n la calidad del proceso de software. d. Desarrollar el c\u00f3digo fuente del software.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 1,
#       "filename": "file.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "d3c74c4658bd5a142944e158c46447d7",
#     "text": "21. \u00bfEn el proceso de \u201crevisi\u00f3n entre colegas\u201d es a toda costa que el autor realice todos los cambios/recomendaciones que los revisores proponen?",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 1,
#       "filename": "file.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "666c949521081aaf928ddfc499bfd58d",
#     "text": "a. S\u00ed, no hacerlo crear\u00eda molestia en el equipo de trabajo. b. S\u00ed, de no ser as\u00ed el autor estar\u00eda fallando en su labor. c. No, siempre y cuando este justificada la omisi\u00f3n del cambio/recomendaci\u00f3n. d. No, el autor tiene mejor conocimiento que cualquier revisor.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 1,
#       "filename": "file.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "d2f3e54307df047412edaa5753e2c3e4",
#     "text": "22. Michael Fagan (cient\u00edfico de IBM), creo el primer m\u00e9todo formal para realizar pruebas en el software. Este m\u00e9todo estructurado fue nombrado como...",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 1,
#       "filename": "file.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "4cfc96c5786624a98680a2e79c3030fd",
#     "text": "a. Inspecciones. b. B\u00fasqueda cuaternaria. c. Revisi\u00f3n entre colegas. d. Pruebas unitarias.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 1,
#       "filename": "file.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "9d0c15a794bf17750b58f2f0ace46caf",
#     "text": "23. En el contexto de las inspecciones, \u00bfqu\u00e9 es un \u201cproducto\u201d?",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 1,
#       "filename": "file.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "ca737cae773b72ffe378a30807dee741",
#     "text": "a. Documento que ser\u00e1 sujeto a inspecci\u00f3n. b. Documento que ser\u00e1 usado como base de una inspecci\u00f3n. c. Documento que nos brinda los requerimientos para realizar. d. Ninguna de las anteriores.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 1,
#       "filename": "file.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "fa88e48f4d1ee4f0a94ab54605d75f36",
#     "text": "24. Son las etapas del procedimiento de inspecci\u00f3n.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 2,
#       "filename": "file.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "f8ca30abaf6e9aa9d8d516ea80b88328",
#     "text": "a. Planeaci\u00f3n de la inspecci\u00f3n, verificaci\u00f3n de criterios de entrada, junta de inicio, inspecci\u00f3n individual, junta de registro, junta de lluvia de ideas, edici\u00f3n, seguimiento y verificaci\u00f3n de criterios de salida. b. Organizaci\u00f3n de la inspecci\u00f3n, verificaci\u00f3n de criterios de entrada, definici\u00f3n de metas, inspecci\u00f3n individual, junta de registro, junta diaria, edici\u00f3n, seguimiento y verificaci\u00f3n de criterios de salida. c. Planeaci\u00f3n de la inspecci\u00f3n, verificaci\u00f3n de criterios m\u00ednimos necesarios, junta de inicio, inspecci\u00f3n general, lista de verificaci\u00f3n, junta de lluvia de ideas, correcci\u00f3n, seguimiento y pruebas de criterios. d. Todas son correctas.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 2,
#       "filename": "file.pdf"
#     }
#   },
#   {
#     "type": "ListItem",
#     "element_id": "34aec3e9afc5310cc3b9a78d16f4aa26",
#     "text": "25. Seg\u00fan el m\u00e9todo de inspecciones as\u00ed se clasifican los defectos.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 2,
#       "filename": "file.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "e60c94270c2aa7cc70bea4b3d0f610d9",
#     "text": "a. Mayores funcionales, mayores no funcionales, menores. b. Altos, medios y bajos. c. Cr\u00edticos, benignos y malignos. d. Buenos, de alto impacto y de bajo impacto.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 2,
#       "filename": "file.pdf"
#     }
#   }
# ]

# %% [markdown]
# ## Clase OCR

# %%
import json
from pathlib import Path
from typing import List, Dict
from unstructured_client import UnstructuredClient
from unstructured_client.models import operations, shared


class OCR:
    def __init__(self):
        self.unstructured_client = UnstructuredClient(server_url="http://localhost:8000")


    def get_ocr(self, file_path: str) -> List[Dict]:
        with open(file_path, "rb") as f:
            data = f.read()

        req = operations.PartitionRequest(
            partition_parameters=shared.PartitionParameters(
                files=shared.Files(
                    content=data,
                    file_name=file_path,
                ),
                strategy=shared.Strategy.AUTO,
                languages=['eng', 'spa'],
                split_pdf_page=True,            # If True, splits the PDF file into smaller chunks of pages.
                split_pdf_allow_failed=True,    # If True, the partitioning continues even if some pages fail.
                split_pdf_concurrency_level=15  # Set the number of concurrent request to the maximum value: 15.
            ),
        )

        try:
            res = self.unstructured_client.general.partition(request=req)
            element_dicts = [element for element in res.elements]
            json_elements = json.dumps(element_dicts, indent=2)

            # Print the processed data.
            print(json_elements)
            return element_dicts

        except Exception as e:
            print(e)


    def get_dev_ocr(self, file_path: str) -> Dict:
        file = Path(file_path)
        metadata = {"filetype": f'text/{file.suffix[1:]}' , "filename": file.name}
        text = file.read_text(encoding='utf-8')
        data = {
            'metadata': metadata, 
            'text': text
        }
        return [data]

# %% [markdown]
# #### Ejemplo de uso

# %%
ocr = OCR()

pdf = ocr.get_ocr("file.pdf")
dev = ocr.get_dev_ocr("salida.txt")
# Out:
# INFO: Preparing to split document for partition.
# INFO: Starting page number set to 1
# INFO: Allow failed set to 1
# INFO: Concurrency level set to 15
# INFO: Splitting pages 1 to 2 (2 total)
# INFO: Determined optimal split size of 2 pages.
# INFO: Document has too few pages (2) to be split efficiently. Partitioning without split.
# INFO: Successfully partitioned the document.
# [
#   {
#     "type": "NarrativeText",
#     "element_id": "084bcfca09086336d78c8ba5c6103a13",
#     "text": "18. Cuando hablamos de capacitaci\u00f3n, tenemos como uno de los beneficios principales, la mejora de la calidad del Software \u00bfA qu\u00e9 nos referimos con esto?",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng",
#         "spa"
#       ],
#       "page_number": 1,
#       "filename": "file.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "f666bfbe7368828ec28fc42ca8724ce3",
#     "text": "a. A un c\u00f3digo bien documentado e indentado. b. A un c\u00f3digo con menos errores, mayor confiabilidad y que genera satisfacci\u00f3n al cliente. c. A un c\u00f3digo que sustituye \u201cifs\u201d por \u201cswitch\u201d para darle mejor presentaci\u00f3n. d. A un c\u00f3digo que utiliza patrones de dise\u00f1o para optimizarse a s\u00ed mismo. 19. \u00bfCu\u00e1l de las siguientes opciones abarca actividades relacionadas con la capacitaci\u00f3n en el contexto de la gesti\u00f3n de la calidad del software seg\u00fan el est\u00e1ndar IEEE-730?",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng",
#         "spa"
#       ],
#       "page_number": 1,
#       "filename": "file.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "4332441c8e57be5ef5b613fa622bdf5c",
#     "text": "a. Entrenamiento en herramientas y tecnolog\u00edas. b. Formaci\u00f3n en metodolog\u00edas y procesos. c. Cumplimiento de est\u00e1ndares y regulaciones. d. Todas las anteriores.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng",
#         "spa"
#       ],
#       "page_number": 1,
#       "filename": "file.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "ae309bf390a880f478d767747f9d71b9",
#     "text": "20. \u00bfCu\u00e1l es uno de los resultados esperados de las mediciones del proceso de software seg\u00fan el est\u00e1ndar IEEE 730-2002?",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng",
#         "spa"
#       ],
#       "page_number": 1,
#       "filename": "file.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "e9d34c7b022c6f34f3fbb498b28f7cbc",
#     "text": "a. Asegurar la conformidad con los est\u00e1ndares de dise\u00f1o. b. Documentar los requisitos del software. c. Representar con precisi\u00f3n la calidad del proceso de software. d. Desarrollar el c\u00f3digo fuente del software.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng",
#         "spa"
#       ],
#       "page_number": 1,
#       "filename": "file.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "d3c74c4658bd5a142944e158c46447d7",
#     "text": "21. \u00bfEn el proceso de \u201crevisi\u00f3n entre colegas\u201d es a toda costa que el autor realice todos los cambios/recomendaciones que los revisores proponen?",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng",
#         "spa"
#       ],
#       "page_number": 1,
#       "filename": "file.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "666c949521081aaf928ddfc499bfd58d",
#     "text": "a. S\u00ed, no hacerlo crear\u00eda molestia en el equipo de trabajo. b. S\u00ed, de no ser as\u00ed el autor estar\u00eda fallando en su labor. c. No, siempre y cuando este justificada la omisi\u00f3n del cambio/recomendaci\u00f3n. d. No, el autor tiene mejor conocimiento que cualquier revisor.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng",
#         "spa"
#       ],
#       "page_number": 1,
#       "filename": "file.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "d2f3e54307df047412edaa5753e2c3e4",
#     "text": "22. Michael Fagan (cient\u00edfico de IBM), creo el primer m\u00e9todo formal para realizar pruebas en el software. Este m\u00e9todo estructurado fue nombrado como...",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng",
#         "spa"
#       ],
#       "page_number": 1,
#       "filename": "file.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "4cfc96c5786624a98680a2e79c3030fd",
#     "text": "a. Inspecciones. b. B\u00fasqueda cuaternaria. c. Revisi\u00f3n entre colegas. d. Pruebas unitarias.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng",
#         "spa"
#       ],
#       "page_number": 1,
#       "filename": "file.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "9d0c15a794bf17750b58f2f0ace46caf",
#     "text": "23. En el contexto de las inspecciones, \u00bfqu\u00e9 es un \u201cproducto\u201d?",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng",
#         "spa"
#       ],
#       "page_number": 1,
#       "filename": "file.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "ca737cae773b72ffe378a30807dee741",
#     "text": "a. Documento que ser\u00e1 sujeto a inspecci\u00f3n. b. Documento que ser\u00e1 usado como base de una inspecci\u00f3n. c. Documento que nos brinda los requerimientos para realizar. d. Ninguna de las anteriores.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng",
#         "spa"
#       ],
#       "page_number": 1,
#       "filename": "file.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "fa88e48f4d1ee4f0a94ab54605d75f36",
#     "text": "24. Son las etapas del procedimiento de inspecci\u00f3n.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng",
#         "spa"
#       ],
#       "page_number": 2,
#       "filename": "file.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "f8ca30abaf6e9aa9d8d516ea80b88328",
#     "text": "a. Planeaci\u00f3n de la inspecci\u00f3n, verificaci\u00f3n de criterios de entrada, junta de inicio, inspecci\u00f3n individual, junta de registro, junta de lluvia de ideas, edici\u00f3n, seguimiento y verificaci\u00f3n de criterios de salida. b. Organizaci\u00f3n de la inspecci\u00f3n, verificaci\u00f3n de criterios de entrada, definici\u00f3n de metas, inspecci\u00f3n individual, junta de registro, junta diaria, edici\u00f3n, seguimiento y verificaci\u00f3n de criterios de salida. c. Planeaci\u00f3n de la inspecci\u00f3n, verificaci\u00f3n de criterios m\u00ednimos necesarios, junta de inicio, inspecci\u00f3n general, lista de verificaci\u00f3n, junta de lluvia de ideas, correcci\u00f3n, seguimiento y pruebas de criterios. d. Todas son correctas.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng",
#         "spa"
#       ],
#       "page_number": 2,
#       "filename": "file.pdf"
#     }
#   },
#   {
#     "type": "ListItem",
#     "element_id": "34aec3e9afc5310cc3b9a78d16f4aa26",
#     "text": "25. Seg\u00fan el m\u00e9todo de inspecciones as\u00ed se clasifican los defectos.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng",
#         "spa"
#       ],
#       "page_number": 2,
#       "filename": "file.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "e60c94270c2aa7cc70bea4b3d0f610d9",
#     "text": "a. Mayores funcionales, mayores no funcionales, menores. b. Altos, medios y bajos. c. Cr\u00edticos, benignos y malignos. d. Buenos, de alto impacto y de bajo impacto.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng",
#         "spa"
#       ],
#       "page_number": 2,
#       "filename": "file.pdf"
#     }
#   }
# ]

# %%
from pprint import pprint

pprint(pdf)
print("-" * 80)
pprint(dev)
# Out:
# [{'element_id': '084bcfca09086336d78c8ba5c6103a13',
#   'metadata': {'filename': 'file.pdf',
#                'filetype': 'application/pdf',
#                'languages': ['eng', 'spa'],
#                'page_number': 1},
#   'text': '18. Cuando hablamos de capacitación, tenemos como uno de los '
#           'beneficios principales, la mejora de la calidad del Software ¿A qué '
#           'nos referimos con esto?',
#   'type': 'NarrativeText'},
#  {'element_id': 'f666bfbe7368828ec28fc42ca8724ce3',
#   'metadata': {'filename': 'file.pdf',
#                'filetype': 'application/pdf',
#                'languages': ['eng', 'spa'],
#                'page_number': 1},
#   'text': 'a. A un código bien documentado e indentado. b. A un código con '
#           'menos errores, mayor confiabilidad y que genera satisfacción al '
#           'cliente. c. A un código que sustituye “ifs” por “switch” para darle '
#           'mejor presentación. d. A un código que utiliza patrones de diseño '
#           'para optimizarse a sí mismo. 19. ¿Cuál de las siguientes opciones '
#           'abarca actividades relacionadas con la capacitación en el contexto '
#           'de la gestión de la calidad del software según el estándar '
#           'IEEE-730?',
#   'type': 'NarrativeText'},
#  {'element_id': '4332441c8e57be5ef5b613fa622bdf5c',
#   'metadata': {'filename': 'file.pdf',
#                'filetype': 'application/pdf',
#                'languages': ['eng', 'spa'],
#                'page_number': 1},
#   'text': 'a. Entrenamiento en herramientas y tecnologías. b. Formación en '
#           'metodologías y procesos. c. Cumplimiento de estándares y '
#           'regulaciones. d. Todas las anteriores.',
#   'type': 'NarrativeText'},
#  {'element_id': 'ae309bf390a880f478d767747f9d71b9',
#   'metadata': {'filename': 'file.pdf',
#                'filetype': 'application/pdf',
#                'languages': ['eng', 'spa'],
#                'page_number': 1},
#   'text': '20. ¿Cuál es uno de los resultados esperados de las mediciones del '
#           'proceso de software según el estándar IEEE 730-2002?',
#   'type': 'NarrativeText'},
#  {'element_id': 'e9d34c7b022c6f34f3fbb498b28f7cbc',
#   'metadata': {'filename': 'file.pdf',
#                'filetype': 'application/pdf',
#                'languages': ['eng', 'spa'],
#                'page_number': 1},
#   'text': 'a. Asegurar la conformidad con los estándares de diseño. b. '
#           'Documentar los requisitos del software. c. Representar con '
#           'precisión la calidad del proceso de software. d. Desarrollar el '
#           'código fuente del software.',
#   'type': 'NarrativeText'},
#  {'element_id': 'd3c74c4658bd5a142944e158c46447d7',
#   'metadata': {'filename': 'file.pdf',
#                'filetype': 'application/pdf',
#                'languages': ['eng', 'spa'],
#                'page_number': 1},
#   'text': '21. ¿En el proceso de “revisión entre colegas” es a toda costa que '
#           'el autor realice todos los cambios/recomendaciones que los '
#           'revisores proponen?',
#   'type': 'NarrativeText'},
#  {'element_id': '666c949521081aaf928ddfc499bfd58d',
#   'metadata': {'filename': 'file.pdf',
#                'filetype': 'application/pdf',
#                'languages': ['eng', 'spa'],
#                'page_number': 1},
#   'text': 'a. Sí, no hacerlo crearía molestia en el equipo de trabajo. b. Sí, '
#           'de no ser así el autor estaría fallando en su labor. c. No, siempre '
#           'y cuando este justificada la omisión del cambio/recomendación. d. '
#           'No, el autor tiene mejor conocimiento que cualquier revisor.',
#   'type': 'NarrativeText'},
#  {'element_id': 'd2f3e54307df047412edaa5753e2c3e4',
#   'metadata': {'filename': 'file.pdf',
#                'filetype': 'application/pdf',
#                'languages': ['eng', 'spa'],
#                'page_number': 1},
#   'text': '22. Michael Fagan (científico de IBM), creo el primer método formal '
#           'para realizar pruebas en el software. Este método estructurado fue '
#           'nombrado como...',
#   'type': 'NarrativeText'},
#  {'element_id': '4cfc96c5786624a98680a2e79c3030fd',
#   'metadata': {'filename': 'file.pdf',
#                'filetype': 'application/pdf',
#                'languages': ['eng', 'spa'],
#                'page_number': 1},
#   'text': 'a. Inspecciones. b. Búsqueda cuaternaria. c. Revisión entre '
#           'colegas. d. Pruebas unitarias.',
#   'type': 'NarrativeText'},
#  {'element_id': '9d0c15a794bf17750b58f2f0ace46caf',
#   'metadata': {'filename': 'file.pdf',
#                'filetype': 'application/pdf',
#                'languages': ['eng', 'spa'],
#                'page_number': 1},
#   'text': '23. En el contexto de las inspecciones, ¿qué es un “producto”?',
#   'type': 'NarrativeText'},
#  {'element_id': 'ca737cae773b72ffe378a30807dee741',
#   'metadata': {'filename': 'file.pdf',
#                'filetype': 'application/pdf',
#                'languages': ['eng', 'spa'],
#                'page_number': 1},
#   'text': 'a. Documento que será sujeto a inspección. b. Documento que será '
#           'usado como base de una inspección. c. Documento que nos brinda los '
#           'requerimientos para realizar. d. Ninguna de las anteriores.',
#   'type': 'NarrativeText'},
#  {'element_id': 'fa88e48f4d1ee4f0a94ab54605d75f36',
#   'metadata': {'filename': 'file.pdf',
#                'filetype': 'application/pdf',
#                'languages': ['eng', 'spa'],
#                'page_number': 2},
#   'text': '24. Son las etapas del procedimiento de inspección.',
#   'type': 'NarrativeText'},
#  {'element_id': 'f8ca30abaf6e9aa9d8d516ea80b88328',
#   'metadata': {'filename': 'file.pdf',
#                'filetype': 'application/pdf',
#                'languages': ['eng', 'spa'],
#                'page_number': 2},
#   'text': 'a. Planeación de la inspección, verificación de criterios de '
#           'entrada, junta de inicio, inspección individual, junta de registro, '
#           'junta de lluvia de ideas, edición, seguimiento y verificación de '
#           'criterios de salida. b. Organización de la inspección, verificación '
#           'de criterios de entrada, definición de metas, inspección '
#           'individual, junta de registro, junta diaria, edición, seguimiento y '
#           'verificación de criterios de salida. c. Planeación de la '
#           'inspección, verificación de criterios mínimos necesarios, junta de '
#           'inicio, inspección general, lista de verificación, junta de lluvia '
#           'de ideas, corrección, seguimiento y pruebas de criterios. d. Todas '
#           'son correctas.',
#   'type': 'NarrativeText'},
#  {'element_id': '34aec3e9afc5310cc3b9a78d16f4aa26',
#   'metadata': {'filename': 'file.pdf',
#                'filetype': 'application/pdf',
#                'languages': ['eng', 'spa'],
#                'page_number': 2},
#   'text': '25. Según el método de inspecciones así se clasifican los defectos.',
#   'type': 'ListItem'},
#  {'element_id': 'e60c94270c2aa7cc70bea4b3d0f610d9',
#   'metadata': {'filename': 'file.pdf',
#                'filetype': 'application/pdf',
#                'languages': ['eng', 'spa'],
#                'page_number': 2},
#   'text': 'a. Mayores funcionales, mayores no funcionales, menores. b. Altos, '
#           'medios y bajos. c. Críticos, benignos y malignos. d. Buenos, de '
#           'alto impacto y de bajo impacto.',
#   'type': 'NarrativeText'}]
# --------------------------------------------------
# [{'metadata': {'filename': 'salida.txt', 'filetype': 'text/txt'},
#   'text': '[\n'
#           '  {\n'
#           '    "type": "NarrativeText",\n'
#           '    "element_id": "084bcfca09086336d78c8ba5c6103a13",\n'
#           '    "text": "18. Cuando hablamos de capacitaci\\u00f3n, tenemos '
#           'como uno de los beneficios principales, la mejora de la calidad del '
#           'Software \\u00bfA qu\\u00e9 nos referimos con esto?",\n'
#           '    "metadata": {\n'
#           '      "filetype": "application/pdf",\n'
#           '      "languages": [\n'
#           '        "eng"\n'
#           '      ],\n'
#           '      "page_number": 1,\n'
#           '      "filename": "file.pdf"\n'
#           '    }\n'
#           '  },\n'
#           '  {\n'
#           '    "type": "NarrativeText",\n'
#           '    "element_id": "f666bfbe7368828ec28fc42ca8724ce3",\n'
#           '    "text": "a. A un c\\u00f3digo bien documentado e indentado. b. '
#           'A un c\\u00f3digo con menos errores, mayor confiabilidad y que '
#           'genera satisfacci\\u00f3n al cliente. c. A un c\\u00f3digo que '
#           'sustituye \\u201cifs\\u201d por \\u201cswitch\\u201d para darle '
#           'mejor presentaci\\u00f3n. d. A un c\\u00f3digo que utiliza patrones '
#           'de dise\\u00f1o para optimizarse a s\\u00ed mismo. 19. '
#           '\\u00bfCu\\u00e1l de las siguientes opciones abarca actividades '
#           'relacionadas con la capacitaci\\u00f3n en el contexto de la '
#           'gesti\\u00f3n de la calidad del software seg\\u00fan el '
#           'est\\u00e1ndar IEEE-730?",\n'
#           '    "metadata": {\n'
#           '      "filetype": "application/pdf",\n'
#           '      "languages": [\n'
#           '        "eng"\n'
#           '      ],\n'
#           '      "page_number": 1,\n'
#           '      "filename": "file.pdf"\n'
#           '    }\n'
#           '  },\n'
#           '  {\n'
#           '    "type": "NarrativeText",\n'
#           '    "element_id": "4332441c8e57be5ef5b613fa622bdf5c",\n'
#           '    "text": "a. Entrenamiento en herramientas y tecnolog\\u00edas. '
#           'b. Formaci\\u00f3n en metodolog\\u00edas y procesos. c. '
#           'Cumplimiento de est\\u00e1ndares y regulaciones. d. Todas las '
#           'anteriores.",\n'
#           '    "metadata": {\n'
#           '      "filetype": "application/pdf",\n'
#           '      "languages": [\n'
#           '        "eng"\n'
#           '      ],\n'
#           '      "page_number": 1,\n'
#           '      "filename": "file.pdf"\n'
#           '    }\n'
#           '  },\n'
#           '  {\n'
#           '    "type": "NarrativeText",\n'
#           '    "element_id": "ae309bf390a880f478d767747f9d71b9",\n'
#           '    "text": "20. \\u00bfCu\\u00e1l es uno de los resultados '
#           'esperados de las mediciones del proceso de software seg\\u00fan el '
#           'est\\u00e1ndar IEEE 730-2002?",\n'
#           '    "metadata": {\n'
#           '      "filetype": "application/pdf",\n'
#           '      "languages": [\n'
#           '        "eng"\n'
#           '      ],\n'
#           '      "page_number": 1,\n'
#           '      "filename": "file.pdf"\n'
#           '    }\n'
#           '  },\n'
#           '  {\n'
#           '    "type": "NarrativeText",\n'
#           '    "element_id": "e9d34c7b022c6f34f3fbb498b28f7cbc",\n'
#           '    "text": "a. Asegurar la conformidad con los est\\u00e1ndares de '
#           'dise\\u00f1o. b. Documentar los requisitos del software. c. '
#           'Representar con precisi\\u00f3n la calidad del proceso de software. '
#           'd. Desarrollar el c\\u00f3digo fuente del software.",\n'
#           '    "metadata": {\n'
#           '      "filetype": "application/pdf",\n'
#           '      "languages": [\n'
#           '        "eng"\n'
#           '      ],\n'
#           '      "page_number": 1,\n'
#           '      "filename": "file.pdf"\n'
#           '    }\n'
#           '  },\n'
#           '  {\n'
#           '    "type": "NarrativeText",\n'
#           '    "element_id": "d3c74c4658bd5a142944e158c46447d7",\n'
#           '    "text": "21. \\u00bfEn el proceso de \\u201crevisi\\u00f3n '
#           'entre colegas\\u201d es a toda costa que el autor realice todos los '
#           'cambios/recomendaciones que los revisores proponen?",\n'
#           '    "metadata": {\n'
#           '      "filetype": "application/pdf",\n'
#           '      "languages": [\n'
#           '        "eng"\n'
#           '      ],\n'
#           '      "page_number": 1,\n'
#           '      "filename": "file.pdf"\n'
#           '    }\n'
#           '  },\n'
#           '  {\n'
#           '    "type": "NarrativeText",\n'
#           '    "element_id": "666c949521081aaf928ddfc499bfd58d",\n'
#           '    "text": "a. S\\u00ed, no hacerlo crear\\u00eda molestia en el '
#           'equipo de trabajo. b. S\\u00ed, de no ser as\\u00ed el autor '
#           'estar\\u00eda fallando en su labor. c. No, siempre y cuando este '
#           'justificada la omisi\\u00f3n del cambio/recomendaci\\u00f3n. d. No, '
#           'el autor tiene mejor conocimiento que cualquier revisor.",\n'
#           '    "metadata": {\n'
#           '      "filetype": "application/pdf",\n'
#           '      "languages": [\n'
#           '        "eng"\n'
#           '      ],\n'
#           '      "page_number": 1,\n'
#           '      "filename": "file.pdf"\n'
#           '    }\n'
#           '  },\n'
#           '  {\n'
#           '    "type": "NarrativeText",\n'
#           '    "element_id": "d2f3e54307df047412edaa5753e2c3e4",\n'
#           '    "text": "22. Michael Fagan (cient\\u00edfico de IBM), creo el '
#           'primer m\\u00e9todo formal para realizar pruebas en el software. '
#           'Este m\\u00e9todo estructurado fue nombrado como...",\n'
#           '    "metadata": {\n'
#           '      "filetype": "application/pdf",\n'
#           '      "languages": [\n'
#           '        "eng"\n'
#           '      ],\n'
#           '      "page_number": 1,\n'
#           '      "filename": "file.pdf"\n'
#           '    }\n'
#           '  },\n'
#           '  {\n'
#           '    "type": "NarrativeText",\n'
#           '    "element_id": "4cfc96c5786624a98680a2e79c3030fd",\n'
#           '    "text": "a. Inspecciones. b. B\\u00fasqueda cuaternaria. c. '
#           'Revisi\\u00f3n entre colegas. d. Pruebas unitarias.",\n'
#           '    "metadata": {\n'
#           '      "filetype": "application/pdf",\n'
#           '      "languages": [\n'
#           '        "eng"\n'
#           '      ],\n'
#           '      "page_number": 1,\n'
#           '      "filename": "file.pdf"\n'
#           '    }\n'
#           '  },\n'
#           '  {\n'
#           '    "type": "NarrativeText",\n'
#           '    "element_id": "9d0c15a794bf17750b58f2f0ace46caf",\n'
#           '    "text": "23. En el contexto de las inspecciones, '
#           '\\u00bfqu\\u00e9 es un \\u201cproducto\\u201d?",\n'
#           '    "metadata": {\n'
#           '      "filetype": "application/pdf",\n'
#           '      "languages": [\n'
#           '        "eng"\n'
#           '      ],\n'
#           '      "page_number": 1,\n'
#           '      "filename": "file.pdf"\n'
#           '    }\n'
#           '  },\n'
#           '  {\n'
#           '    "type": "NarrativeText",\n'
#           '    "element_id": "ca737cae773b72ffe378a30807dee741",\n'
#           '    "text": "a. Documento que ser\\u00e1 sujeto a inspecci\\u00f3n. '
#           'b. Documento que ser\\u00e1 usado como base de una '
#           'inspecci\\u00f3n. c. Documento que nos brinda los requerimientos '
#           'para realizar. d. Ninguna de las anteriores.",\n'
#           '    "metadata": {\n'
#           '      "filetype": "application/pdf",\n'
#           '      "languages": [\n'
#           '        "eng"\n'
#           '      ],\n'
#           '      "page_number": 1,\n'
#           '      "filename": "file.pdf"\n'
#           '    }\n'
#           '  },\n'
#           '  {\n'
#           '    "type": "NarrativeText",\n'
#           '    "element_id": "fa88e48f4d1ee4f0a94ab54605d75f36",\n'
#           '    "text": "24. Son las etapas del procedimiento de '
#           'inspecci\\u00f3n.",\n'
#           '    "metadata": {\n'
#           '      "filetype": "application/pdf",\n'
#           '      "languages": [\n'
#           '        "eng"\n'
#           '      ],\n'
#           '      "page_number": 2,\n'
#           '      "filename": "file.pdf"\n'
#           '    }\n'
#           '  },\n'
#           '  {\n'
#           '    "type": "NarrativeText",\n'
#           '    "element_id": "f8ca30abaf6e9aa9d8d516ea80b88328",\n'
#           '    "text": "a. Planeaci\\u00f3n de la inspecci\\u00f3n, '
#           'verificaci\\u00f3n de criterios de entrada, junta de inicio, '
#           'inspecci\\u00f3n individual, junta de registro, junta de lluvia de '
#           'ideas, edici\\u00f3n, seguimiento y verificaci\\u00f3n de criterios '
#           'de salida. b. Organizaci\\u00f3n de la inspecci\\u00f3n, '
#           'verificaci\\u00f3n de criterios de entrada, definici\\u00f3n de '
#           'metas, inspecci\\u00f3n individual, junta de registro, junta '
#           'diaria, edici\\u00f3n, seguimiento y verificaci\\u00f3n de '
#           'criterios de salida. c. Planeaci\\u00f3n de la inspecci\\u00f3n, '
#           'verificaci\\u00f3n de criterios m\\u00ednimos necesarios, junta de '
#           'inicio, inspecci\\u00f3n general, lista de verificaci\\u00f3n, '
#           'junta de lluvia de ideas, correcci\\u00f3n, seguimiento y pruebas '
#           'de criterios. d. Todas son correctas.",\n'
#           '    "metadata": {\n'
#           '      "filetype": "application/pdf",\n'
#           '      "languages": [\n'
#           '        "eng"\n'
#           '      ],\n'
#           '      "page_number": 2,\n'
#           '      "filename": "file.pdf"\n'
#           '    }\n'
#           '  },\n'
#           '  {\n'
#           '    "type": "ListItem",\n'
#           '    "element_id": "34aec3e9afc5310cc3b9a78d16f4aa26",\n'
#           '    "text": "25. Seg\\u00fan el m\\u00e9todo de inspecciones '
#           'as\\u00ed se clasifican los defectos.",\n'
#           '    "metadata": {\n'
#           '      "filetype": "application/pdf",\n'
#           '      "languages": [\n'
#           '        "eng"\n'
#           '      ],\n'
#           '      "page_number": 2,\n'
#           '      "filename": "file.pdf"\n'
#           '    }\n'
#           '  },\n'
#           '  {\n'
#           '    "type": "NarrativeText",\n'
#           '    "element_id": "e60c94270c2aa7cc70bea4b3d0f610d9",\n'
#           '    "text": "a. Mayores funcionales, mayores no funcionales, '
#           'menores. b. Altos, medios y bajos. c. Cr\\u00edticos, benignos y '
#           'malignos. d. Buenos, de alto impacto y de bajo impacto.",\n'
#           '    "metadata": {\n'
#           '      "filetype": "application/pdf",\n'
#           '      "languages": [\n'
#           '        "eng"\n'
#           '      ],\n'
#           '      "page_number": 2,\n'
#           '      "filename": "file.pdf"\n'
#           '    }\n'
#           '  }\n'
#           ']'}]
