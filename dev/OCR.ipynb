# %% [markdown]
# # OCR

# %% [markdown]
# ## With Unstructured.io
#
# Hacer las peticiones al `http://localhost:8000`
#
# Con el siguente comando se puede correr el contenedor de UNSTRUCTURED (con la opcion de `--rm` para que se elimine el contenedor al detenerlo):
#
# ```bash
# docker run -p 8000:8000 -d --rm --name unstructured-api downloads.unstructured.io/unstructured-io/unstructured-api:latest --port 8000 --host 0.0.0.0
# ```
#
# _Sin la opcion `--rm`:_
# ```bash
# docker run -p 8000:8000 -d --name unstructured-api downloads.unstructured.io/unstructured-io/unstructured-api:latest --port 8000 --host 0.0.0.0
# ```
#
# *Más imformación sobre la imagen: ([UnstructuredLoader | 🦜️🔗 Langchain](https://js.langchain.com/v0.2/docs/integrations/document_loaders/file_loaders/unstructured/))*
#
# *Más imformación sobre el SDK de Python: [Process an individual file by using the Unstructured Python SDK - Unstructured](https://docs.unstructured.io/api-reference/api-services/sdk-python)*

# %%
# Dependencies for unstructured

# %pip install unstructured-client

# %% [markdown]
# Prueba con el siguiente bloque de codigo que hace la peticion al contenedor de UNSTRUCTURED, el cual se encarga de hacer el OCR a un archivo PDF; para despues guardar la salida en un archivo de texto.
#
# ```python
# import os
# import json
# import unstructured_client
# from unstructured_client.models import operations, shared
#
# client = unstructured_client.UnstructuredClient(
#     server_url="http://localhost:8000",
# )
#
# filename = "file.pdf"
# with open(filename, "rb") as f:
#     data = f.read()
#
# req = operations.PartitionRequest(
#     partition_parameters=shared.PartitionParameters(
#         files=shared.Files(
#             content=data,
#             file_name=filename,
#         ),
#         strategy=shared.Strategy.HI_RES,
#         languages=['eng'],
#         split_pdf_page=True,            # If True, splits the PDF file into smaller chunks of pages.
#         split_pdf_allow_failed=True,    # If True, the partitioning continues even if some pages fail.
#         split_pdf_concurrency_level=15  # Set the number of concurrent request to the maximum value: 15.
#     ),
# )
#
# try:
#     res = client.general.partition(request=req)
#     element_dicts = [element for element in res.elements]
#     json_elements = json.dumps(element_dicts, indent=2)
#
#     # Print the processed data.
#     print(json_elements)
#
#     # Write the processed data to a local file.
#     with open("salida.txt", "w") as file:
#         file.write(json_elements)
# except Exception as e:
#     print(e)
# ```
#
# ### Clase OCR
#
# En la clase `OCR` se encuentra el metodo `get_ocr()` que en este caso se encarga de hacer el OCR a archivos de tipo PDF o rtf.
# Tambien se cuenta con el metodo `get_dev_ocr()` que es el encargado de hacer la extracción de texto de archivos de texto plano.
#
# **IMPORTANTE:**
# Hay problemas con la concurrencia

# %%
import json
from pathlib import Path
from typing import List, Dict
from unstructured_client import UnstructuredClient
from unstructured_client.models import operations, shared


class OCR:
    def __init__(self):
        self.unstructured_client = UnstructuredClient(server_url="http://localhost:8000")

    def get_ocr(self, file_path: str) -> List[Dict]:
        with open(file_path, "rb") as f:
            data = f.read()

        req = operations.PartitionRequest(
            partition_parameters=shared.PartitionParameters(
                files=shared.Files(
                    content=data,
                    file_name=file_path,
                ),
                strategy=shared.Strategy.AUTO,
                languages=['eng', 'spa'],
                split_pdf_page=False,            # If True, splits the PDF file into smaller chunks of pages.
                # split_pdf_allow_failed=True,    # If True, the partitioning continues even if some pages fail.
                # split_pdf_concurrency_level=15  # Set the number of concurrent request to the maximum value: 15.
            ),
        )
        try:
            res = self.unstructured_client.general.partition(request=req)
            element_dicts = [element for element in res.elements]
            json_elements = json.dumps(element_dicts, indent=2)

            # Print the processed data.
            print(json_elements)
            return element_dicts
        except Exception as e:
            print(e)

    def get_dev_ocr(self, file_path: str) -> Dict:
        file = Path(file_path)
        metadata = {"filetype": f'text/{file.suffix[1:]}' , "filename": file.name}
        text = file.read_text(encoding='utf-8')
        data = {
            'metadata': metadata, 
            'text': text
        }
        return [data]

# %% [markdown]
# ---
#
# ## Without Unstructured.io
#
# Unstructured.io es una herramienta poderosa, pero aparte de que tiene opciones de pago para mejor rendimiento, es bastante tardado hacer el OCR de documentos con elementos complejos (como imagenes, tablas, listas, etc.). Por lo que se encontro una alternativa que puede ser la libreria de ["pymupdf/PyMuPDF: PyMuPDF is a high performance Python library for data extraction, analysis, conversion & manipulation of PDF (and other) documents."](https://github.com/pymupdf/PyMuPDF) para hacer la extracción de texto a archivos PDF.
#
# Los archivos PDF generalmente contienen imagenes, tablas, listas, etc. Por lo que primero se puede aplicar una capa de OCR al documento, para que la extracción de texto sea mas precisa como con un OCR de Unstructured.
#
# Para agregar la capa de OCR a un archivo PDF se puede hacer con la herramienta de ["ocrmypdf/OCRmyPDF: OCRmyPDF adds an OCR text layer to scanned PDF files, allowing them to be searched"](https://github.com/ocrmypdf/OCRmyPDF).
# OCRmyPDF ocupa la libreria de ["tesseract-ocr/tesseract: Tesseract Open Source OCR Engine"](https://github.com/tesseract-ocr/tesseract) para hacer el OCR a los archivos PDF. Por lo que primero se debe instalar la libreria de tesseract-ocr y despues instalar OCRmyPDF.
#
# Como OCRmyPDF es una herramienta de linea de comandos, se puede hacer uso de la libreria de `subprocess` para hacer uso de OCRmyPDF en Python.
#
# ```python
# import subprocess
# import os
#
# def ocr_pdf(input_pdf, output_pdf, language='eng+spa'):
#     """
#     Aplica OCR a un archivo PDF usando OCRmyPDF.
#
#     :param input_pdf: Ruta al archivo PDF de entrada.
#     :param output_pdf: Ruta al archivo PDF de salida.
#     :param language: Idioma para OCR (por defecto 'eng+spa' para español).
#     """
#     try:
#         # Construir el comando
#         comando = [
#             'ocrmypdf',
#             '-l', language,
#             '--force-ocr',
#             '--jobs', '6',
#             '--output-type', 'pdf',
#             input_pdf,
#             output_pdf
#         ]
#
#         # Ejecutar el comando
#         subprocess.run(comando, check=True)
#         print(f"OCR aplicado exitosamente a {input_pdf}. Salida: {output_pdf}")
#     except subprocess.CalledProcessError as e:
#         print(f"Error al aplicar OCR: {e}")
#
# # Uso del script
# if __name__ == "__main__":
#     ruta_input = "ruta al archivo PDF de entrada"
#     ruta_output = "ruta al archivo PDF de salida (puede ser el mismo archivo)"
#
#     # Verificar si el archivo de entrada existe
#     if os.path.exists(ruta_input):
#         ocr_pdf(ruta_input, ruta_output)
#     else:
#         print(f"El archivo {ruta_input} no existe.")
# ```
#
# ### Clase OCR
#
# En la clase `OCR` se encuentra el metodo `get_ocr()` que en este caso se encarga de hacer la extracción de texto de archivos PDF con la capa de OCR aplicada.
# Este metodo manda llamar a la funcion `ocr_pdf()` que se encarga de aplicar la capa de OCR a un archivo PDF.
# Tambien se cuenta con el mismo metodo `get_dev_ocr()` que es el encargado de hacer la extracción de texto de archivos de texto plano.

# %%
# Dependencies for PyMuPDF

# %pip install PyMuPDF

# %%
import subprocess
from pathlib import Path
from typing import List, Dict, Union
import pymupdf


class OCR:
    def ocr_pdf(self, input_pdf: Union[str, Path], output_pdf: Union[str, Path], language='eng+spa') -> None:
        """
        Aplica OCR a un archivo PDF usando OCRmyPDF.

        :param input_pdf: Ruta al archivo PDF de entrada.
        :param output_pdf: Ruta al archivo PDF de salida.
        :param language: Idioma para OCR (por defecto 'eng+spa' para ingles y español).
        """
        try:
            # Construir el comando
            comando = [
                'ocrmypdf',
                '-l', language,
                '--force-ocr',
                '--jobs', '6',
                '--output-type', 'pdf',
                input_pdf if isinstance(input_pdf, str) else input_pdf.resolve(),
                output_pdf if isinstance(output_pdf, str) else output_pdf.resolve()
            ]

            # Ejecutar el comando
            subprocess.run(comando, check=True)
            print(f"OCR aplicado exitosamente a {input_pdf}. Salida: {output_pdf}")
        except subprocess.CalledProcessError as e:
            print(f"Error al aplicar OCR: {e}")

    def get_ocr(self, file_path: str) -> List[Dict]:
        self.ocr_pdf(file_path, file_path)
        file = Path(file_path)
        elements = []
        metadata = {
            'filetype': 'application/pdf',
            'filename': file.name,
            'page_number': 0
        }
        doc = pymupdf.open(file.resolve())  # open a document
        for page in doc:
            metadata_copy = metadata.copy()  # Crear una copia del diccionario
            metadata_copy['page_number'] = page.number + 1
            elements.append({
                'metadata': metadata_copy,
                'text': page.get_text().encode('utf-8')
            })
        return elements
        
    def get_dev_ocr(self, file_path: str) -> List:
        file = Path(file_path)
        metadata = {"filetype": f'text/{file.suffix[1:]}' , "filename": file.name}
        text = file.read_text(encoding='utf-8')
        data = {
            'metadata': metadata, 
            'text': text
        }
        return [data]

# %% [markdown]
# #### Ejemplo de uso

# %%
ocr = OCR()

data = ocr.get_ocr('/Users/jorge-jrzz/Downloads/revista perros.pdf')
data
# Out:
# Start processing 6 pages concurrently
#     2 page already has text! - rasterizing text and running OCR anyway
#     3 page already has text! - rasterizing text and running OCR anyway
#     4 page already has text! - rasterizing text and running OCR anyway
#     5 page already has text! - rasterizing text and running OCR anyway
#     6 page already has text! - rasterizing text and running OCR anyway
#     7 page already has text! - rasterizing text and running OCR anyway
#     7 Weighted average image DPI is 101.5, max DPI is 129.1. The discrepancy may indicate a high detail region on this page, but could also indicate a problem with the input PDF file. Page image will be rendered at 400.0 DPI.
#     8 page already has text! - rasterizing text and running OCR anyway
#     9 page already has text! - rasterizing text and running OCR anyway
#    10 page already has text! - rasterizing text and running OCR anyway
#    10 [tesseract] lots of diacritics - possibly poor OCR
# Postprocessing...
# Image optimization ratio: 1.09 savings: 8.1%
# Total file size ratio: 0.40 savings: -148.3%
# OCR aplicado exitosamente a /Users/jorge-jrzz/Downloads/revista perros.pdf. Salida: /Users/jorge-jrzz/Downloads/revista perros.pdf
# [{'metadata': {'filetype': 'application/pdf',
#    'filename': 'revista perros.pdf',
#    'page_number': 1},
#   'text': b'Revista veterinaria profesional\n(a de animales de compa\xc3\xb1\xc3\xada\nN\xc2\xb0 130 - Octubre 2014\n5 (2014) - A\xc3\xb1o XXII\nEl laboratorio en tu clinica Cn de\nwww.ciab.es | rodrigo@ciab.es | 91 3613314 Investigacion y\noslada 12. Baio Drcha. 28028 Madrid Analisis Biologicos\n'},
#  {'metadata': {'filetype': 'application/pdf',
#    'filename': 'revista perros.pdf',
#    'page_number': 2},
#   'text': b'18\na GENETICA DE PERROS Y GATOS: PATOLOGIAS HEREDITARIAS\nCANIf-FELIf | Y OTROS ASPECTOS DE INTER\xc3\x89S EN LA CL\xc3\x8dNICA VETERINARIA :\nOrigen y diversidad\nde la especie canina\nDunner S, Ca\xc3\xb1\xc3\xb3n J\nLaboratorio de Gen\xc3\xa9tica. Dpto. de Producci\xc3\xb3n Animal. Facultad de Veterinaria, UCM.\nDesde el inicio del proceso de domesticacion del perro, hace unos 11.000-16.000\nanos a partir de poblaciones de lobo, el ancestro salvaje del perro, el patron actual\nde diferenciacion es consecuencia de un proceso evolutivo reticulado, implicando\nmultiples eventos de migraci\xc3\xb3n, introgresi\xc3\xb3n y aislamiento reproductivo que ha dado\nlugar a un gran numero de razas, con una elevada variabilidad interracial. Por otro\nlado, este elevado grado de diferenciaci\xc3\xb3n gen\xc3\xa9tica entre razas, y la abundante infor-\nmaci\xc3\xb3n molecular disponible en esta especie desde la secuenciaci\xc3\xb3n de su genoma,\npermiten, entre otras aplicaciones que se describen en este capitulo, determinar con\ngran precision el origen racial de un determinado ejemplar, incluso la proporcion de\ngenoma que proviene de cada una de las razas que puede haber estado en el origen\nde un determinado ejemplar.\nCanis et Felis # Numero 130 - Octubre 2014\n'},
#  {'metadata': {'filetype': 'application/pdf',
#    'filename': 'revista perros.pdf',
#    'page_number': 3},
#   'text': b"Origen y diversidad de la especie canina\n= LA ESPECIE CANINA\nPara qui\xc3\xa9n se interesa a la especie canina, es llamativo constatar la diversidad tanto\nmorfologica como de comportamiento que muestran sus representantes. Con unos\nest\xc3\xa1ndares de tamanos\n \ny de peso que var\xc3\xadan de 18 a 90 cm y de 0,5 a 100 kg en funci\xc3\xb3n\nde las razas [por ejemplo entre el chihuahua y el mastin], no existe ninguna especie de\nmamifero que muestre una variabilidad morfol\xc3\xb3gica tan grande. Esta heterogeneidad\ntambi\xc3\xa9n es fisiol\xc3\xb3gica: existen diferentes poblaciones en las que las esperanzas de\nvida varian de 6 a 14 anos y el tama\xc3\xb1o de camada es de 2 a 8 cachorros.\nAdemas, la sociabilizaci\xc3\xb3n y la plasticidad de los caracteres de comportamiento\nen la especie le ha permitido ser apta para una gama muy variada de usos: unos\ndatan de los primeros tiempos de la domesticaci\xc3\xb3n [caza, compa\xc3\xb1\xc3\xada, guarda,\neliminaci\xc3\xb3n de basuras, fuente de alimentaci\xc3\xb3n), otros [salvamento, aduanas,\nperros lazarillos) se han desarrollado mucho mas recientemente. Hay que re-\ncalcar que no existe una especie dom\xc3\xa9stica con tantos usos diferentes como el\nperro: caza, guarda (de reba\xc3\xb1os, de casas...], compa\xc3\xb1\xc3\xada, ayuda a la seguridad y/o\nsocorro [perros polic\xc3\xada, perros aduana, perros de avalancha, ayuda a los disca-\npacitados [perros lazarillos, tracci\xc3\xb3n de vehiculos ligeros), carrera, ayuda para\nbuscar alimentos [perros trufa], alimento para el hombre [en algunas\nregiones del planeta]. Esta diversidad de usos solo ha podido ser posible\ngracias a una gran plasticidad morfol\xc3\xb3gica y comportamental de la especie.\nConviene buscar las razones de esta variabilidad. Segun algunos autores, esta\ndiferenciaci\xc3\xb3n morfol\xc3\xb3gica de los canidos es esencialmente postnatal y ligada en\nparte a la neotenizaci\xc3\xb3n' que muestra la especie. Otra hip\xc3\xb3tesis se basa en la\nexistencia de un numero especialmente importante de mutaciones producidas\npor deslizamiento en genes que corresponden al desarrollo ontog\xc3\xa9nico!. Una va-\nriabilidad de las repeticiones nucleotidicas en estos genes conllevaria variaciones\nmorfoldgicas importantes. Esta particularidad de los canidos en general se debe-\nria a un defecto en los mecanismos de reparaci\xc3\xb3n del genoma. Las mutaciones\npor deslizamiento, siendo 100.000 veces mas frecuentes que las mutaciones por\ninsercion, serian la causa de esa plasticidad morfoldgica, y explicarian el elevado\npotencial evolutivo de la especie canina. Esa plasticidad ha permitido que algunas\nrazas se adapten a las condiciones impuestas por el hombre como, por ejemplo,\nla selecci\xc3\xb3n de los individuos de la raza pastor alem\xc3\xa1n y pastor belga que han pa-\nsado a partir en el siglo XX de ser perros pastor a ser perros de defensa.\nNo hay duda de que el perro es la primera especie domesticada por el hombre.\nLa evidencia arqueol\xc3\xb3gica indica que el perro actual ya se parec\xc3\xada al perro de\nhace unos 10.000\n! Capacidad de mantener rasgos juveniles en la edad adulta.\n* Genes que intervienen en el desarrollo de un organismo.\nNumero 130 - Octubre 2014 # Canis et Felis\n"},
#  {'metadata': {'filetype': 'application/pdf',
#    'filename': 'revista perros.pdf',
#    'page_number': 4},
#   'text': b'20\na GENETICA DE PERROS Y GATOS: PATOLOGIAS HEREDITARIAS\nCANIf-FELIf | Y OTROS ASPECTOS DE INTER\xc3\x89S EN LA CL\xc3\x8dNICA VETERINARIA :\na\xc3\xb1os, sin embargo la evidencia gen\xc3\xb3mica sugiere que el perro ha podido diver-\ngir de otros c\xc3\xa1nidos hace unos 100.000 a\xc3\xb1os. Al margen de cu\xc3\xa1l puede ser la\nfecha de nacimiento oficial del perro como (sub]-especie, se trata de un lapso de\ntiempo corto en relaci\xc3\xb3n con la edad del Homo sapiens.\nRazones para la domesticaci\xc3\xb3n del perro\nExisten varias hip\xc3\xb3tesis sobre el a los procesos de domesticaci\xc3\xb3n del lobo sien-\ndo, en todo caso, el resultado de un largo periodo de cohabitaci\xc3\xb3n entre las dos\nespecies. Una hip\xc3\xb3tesis supone gue ha habido una sociabilizaci\xc3\xb3n sucesiva de\nlobeznos que posteriormente han permanecido en los asentamientos humanos.\nEl hombre habria seleccionado el lobo utilizando criterios de comportamiento\nque favorecen la cercan\xc3\xada primero y luego la utilizaci\xc3\xb3n. Algunos autores se in-\nclinan porque estas primeras tentativas estarian marcadas por una necesidad de\ndescubrir y una voluntad de apropiarse de lo vivo sin voluntad utilitarista en un\nprincipio. Otros autores determinan que hubo una auto-domesticaci\xc3\xb3n de ciertas\npoblaciones de lobo cuyos Individuos se acercaban a los campamentos humanos\npara aprovecharse de sus restos, lo que le hubiera dado una ventaja selectiva. Los\nanimales menos miedosos se habrian auto-seleccionado hasta dar lugar a una\npoblaci\xc3\xb3n que tuviera el mismo modo de vida que ciertas poblaciones de perros de\npueblo semisalvajes (village dogs] hoy en dia. Este lobo \xe2\x80\x9cpredomesticado\xe2\x80\x9d habr\xc3\xada\nsido seleccionado por parte del hombre con objetivos utilitarios.\nHoy en dia, no hay ninguna duda de que el lobo prehist\xc3\xb3rico ha sido el ancestro\nsalvaje del perro dom\xc3\xa9stico. Las [sub]-especies canina y lupina, completamente\ninter-f\xc3\xa9rtiles, son muy pr\xc3\xb3ximas gen\xc3\xa9ticamente, y no difieren mas que en un 0,2%\nde su ADN mitocondrial frente a un 0,4% en comparaci\xc3\xb3n con otros canidos. En el\narbol filogen\xc3\xa9tico que se puede construir para la familia de los c\xc3\xa1nidos, el perro y\nel lobo no solo comparten una de las tres ramas del \xc3\xa1rbol filogen\xc3\xa9tico (las otras\ndos ramas re\xc3\xbanen diferentes especies de zorros] junto con el coyote y el chacal,\nsino que son las dos especies mas proximas.\nLas pruebas paleontologicas del perro datan del pleistoceno medio y se situan\nentre 14.000 y 20.000 anos antes de nuestra era. Se trata de representaciones\nrupestres, asi como de huesos identificados como morfol\xc3\xb3gicamente distintos de\nlos de lobos. Se encontraron restos de un perro en el sitio Jiahu, de la provincia\nde Henan, en China gue datan del neolitico bajo [hace de 9.000 a 7.800 a\xc3\xb1os) y en\nAlemania se ha encontrado un lugar de sepulturas, denominado Bonn Oberkas-\nsel, que contiene restos de humanos y de perros gue datan de unos 14.000 anos.\nLos datos de gen\xc3\xa9tica molecular, hasta ahora, no habian permitido precisar la\n\xc3\xa9poca de la domesticaci\xc3\xb3n, con ADN mitocondrial unos autores sugerian cifras\nde mas de 100.000 anos de divergencia entre las dos especies, pero otros traba-\njos mas recientes permiten hablar de ~15.000 anos. Existen diferentes elementos\nque permiten suponer que el centro de domesticaci\xc3\xb3n de la especie se situd en el\nsureste de Asia: a] las comparaciones morfoldgicas entre fosiles y perros actuales\nmostraban que los perros del continente americano son mas proximos a un lobo\nCanis et Felis # Numero 130 - Octubre 2014\n'},
#  {'metadata': {'filetype': 'application/pdf',
#    'filename': 'revista perros.pdf',
#    'page_number': 5},
#   'text': b'Origen y diversidad de la especie canina\nchino del pleistoceno. b] Las poblaciones de perros del sureste de Asia presentan\nuna mayor diversidad molecular\n \ny por ello se habla de una domesticaci\xc3\xb3n extre-\nmo-oriental. Sin embargo, otros resultados posteriores contradicen esta teoria y\nsugieren eventos de domesticaci\xc3\xb3n, multiples e independientes, tanto en Europa\ncomo en Asia. Utilizando chips de 48.000 marcadores de tipo SNP y an\xc3\xa1lisis de\nbloques haplotipicos, unos autores muestran en 2011 que los lobos americanos,\nel lobo de los Grandes Lagos, y el lobo rojo, son el resultado de la hibridaci\xc3\xb3n\nde variedades derivadas del lobo gris y del coyote respectivamente. Esta historia\ngenomica divergente sugiere que no tienen un ancestro com\xc3\xban reciente, y que si-\ngue existiendo una hibridaci\xc3\xb3n interespecifica en la actualidad. Claramente estos\nresultados no reflejan que el origen del perro sea Asia oriental, sino que sugieren\nbien la existencia de otros origenes, de retrocruzamientos antiguos 0, por ultimo,\nindican un sesgo en la variaci\xc3\xb3n de ADN mitocondrial debido a la posible mayor\ndispersion de las hembras. Actualmente, las herramientas moleculares disponi-\nbles [con las que se puede comparar no s\xc3\xb3lo regiones cromos\xc3\xb3micas en forma de\nhaplotipos sino genomas completos], permiten detectar un modelo demografico\nen el cual perros y lobos sufrieron hibridaciones constantes para luego divergir a\ntrav\xc3\xa9s de un proceso din\xc3\xa1mico que incluye cuellos de botella [es decir una reduc-\nci\xc3\xb3n dr\xc3\xa1stica de su poblaci\xc3\xb3n original] en ambos linajes, y el establecimiento de\nun flujo de genes entre las dos especies posterior a esa divergencia.\nEn el perro, se ha detectado un cuello de botella producido por la domesticaci\xc3\xb3n\nque supuso una reducci\xc3\xb3n del censo efectivo? de poblaci\xc3\xb3n [-16 veces], lo que\nrepresenta una reducci\xc3\xb3n mucho m\xc3\xa1s dr\xc3\xa1stica de lo que se hab\xc3\xada estimado ante-\nriormente. En el lobo se produjo un cuello de botella muy pronto despu\xc3\xa9s de la di-\nvergencia con el perro, lo que sugiere que el\n \npool de diversidad a partir del cual se\ngener\xc3\xb3 el perro era sustancialmente mayor que el representado por las poblacio-\nnes modernas de lobo. Con los datos de secuenciaci\xc3\xb3n de lobos grises actuales,\nprocedentes de tres de los centros putativos de domesticaci\xc3\xb3n del perro (China,\nIsrael, y Croacia}, junto con los de dos razas caninas oriundas de dos areas his-\ntoricamente aisladas de las poblaciones modernas de lobo, una de Africa central\n[basenji] y otra de Australia [dingo], y los datos de un chacal dorado [muy alejado\nde todos ellos], se ha obtenido una estimaci\xc3\xb3n de entre 11 y 16.000 a\xc3\xb1os para el\nintervalo en el que se produjo la domesticaci\xc3\xb3n. Por lo tanto estos datos sugieren\nque el perro aparecid acompanando al hombre cazador-recolector mas que al\nhombre agricultor. Lo mas curioso de este ultimo trabajo es que ninguno de los\nlobos actuales procedentes de los centros tenidos como de domesticaci\xc3\xb3n es mas\ncercano al perro, sino que todo Indica que ambos pertenecen a ramas hermanas\nde un arbol evolutivo encabezado por un lobo ancestral que se extingui\xc3\xb3 y que dio\nlugar tanto a lobos como a perros actuales, como lo demuestra la presencia, tanto\n* El censo efectivo (N) de una poblaci\xc3\xb3n es una cifra te\xc3\xb3rica que representa el censo de reproductores de la\npoblaci\xc3\xa9n tal que si se cruzan de forma equilibrada darian lugar a la endogamia actual observada en dicha\npoblaci\xc3\xb3n. El inter\xc3\xa9s de este concepto es consecuencia de su relaci\xc3\xb3n con el incremento por generaci\xc3\xb3n en endo\n1\ngamia (AF) tal y como figura en la ecuaci\xc3\xb3n siguiente: N = OAR\xe2\x80\x9d\nNumero 130 - Octubre 2014 # Canis et Felis\n21\n'},
#  {'metadata': {'filetype': 'application/pdf',
#    'filename': 'revista perros.pdf',
#    'page_number': 6},
#   'text': b'22\na GENETICA DE PERROS Y GATOS: PATOLOGIAS HEREDITARIAS\nCANIf-FELIf | Y OTROS ASPECTOS DE INTER\xc3\x89S EN LA CL\xc3\x8dNICA VETERINARIA\nen la raza canina basenji, como en el dingo, y en los llamados \xe2\x80\x9cperros de pueblo\xe2\x80\x9d\no villaje dogs [perros asiaticos que siguen manteniendo el mismo estilo de vida que\nhace 15.000 anos y no han sufrido ninguna selecci\xc3\xb3n por parte del hombre], de la\nmisma mezcla en su genoma de lobo y perro (Figura 1).\nOtro elemento de inter\xc3\xa9s en el estudio del proceso de domesticaci\xc3\xb3n del perro es\nel numero de copias presentes en cada poblaci\xc3\xb3n del gen de la Amilasa, AMY2B.\nSe cree gue este gen ha sido clave para gue el perro se adapte a las poblaciones\nhumanas agricolas porque ayuda a la digestion del almid\xc3\xb3n procedente de los\ncereales que el hombre empez\xc3\xb3 a cultivar. Cuantas mas copias de este gen tiene\nun individuo mas f\xc3\xa1cilmente digerir\xc3\xa1 el almid\xc3\xb3n que esta incluido en su dieta \xe2\x80\x9cdo-\nM\xc3\xa9stica\xe2\x80\x9d. Curiosamente, existen grandes variaciones en el numero de copias de\neste gen en los lobos y muy pocas copias en los linajes del dingo y el husky. Esto\nSugiere que al principio de la domesticaci\xc3\xb3n los perros se caracterizaban por una\ndieta mas carnivora que la de los perros actuales, que era la dieta del hombre\nprehist\xc3\xb3rico, y por lo tanto que la domesticaci\xc3\xb3n no es un evento simple ni se ha\nproducido cuando el hombre se ha vuelto sedentario sino mucho antes.\nMILES\n \nDE\n \nANOS\n \nATRAS\n \n(KANOS)\nCanis et Felis # Numero 130 - Octubre 2014\n'},
#  {'metadata': {'filetype': 'application/pdf',
#    'filename': 'revista perros.pdf',
#    'page_number': 7},
#   'text': b'Origen y diversidad de la especie canina\nRazas de perros\nUna de las consecuencias de la domesticacion ha consistido en ciertas modifica-\nclones morfol\xc3\xb3gicas encontradas en el perros primitivos: modificaciones faciales,\nreduccion del tamano de los dientes etc. Segun ciertas hip\xc3\xb3tesis, estos cambios\nmorfoldgicos intimamente correlacionados con una selecci\xc3\xb3n sobre el comporta-\nmiento, estarian ligados a modificaciones hormonales. Al seleccionar zorros con\nel criterio de docilidad durante una docena de generaciones se han observado\nmodificaciones morfol\xc3\xb3gicas y en paralelo una disminuci\xc3\xb3n de la tasa media de\ncortico-esteroides [hormonas ligadas al estr\xc3\xa9s). Las modificaciones hormonales\ntendr\xc3\xadan consecuencias importantes sobre el desarrollo de la ontog\xc3\xa9nesis. Estos\nresultados vendr\xc3\xadan a decir que con la reproducci\xc3\xb3n de los animales m\xc3\xa1s d\xc3\xb3ciles\ny los menos sensibles al estr\xc3\xa9s se seleccionaba indirectamente sobre la tasa de\nhormonas, lo que habr\xc3\xada provocado las primeras modificaciones morfol\xc3\xb3gicas del\nlobo hacia un tipo de perro primitivo. Aunque esto no explica los precoces eleva-\ndos niveles de diversidad racial en la especie canina observados en los abundan-\ntes testimonios arqueo-zooldgicos. Pinturas rupestres encontradas en Turquia,\ny que datan de 5.850 antes de nuestra era, muestran perros de tipo moloso, se\nhan descubierto representaciones\nde individuos de tipo graioide [tipo\ngalgo) en pinturas y cer\xc3\xa1micas del\n49 milenio antes de nuestra era en el\nmediano oriente y en cuevas de Ar-\ngelia, se han descubierto esqueletos\nde perros en Italia que muestran la\nvariabilidad de tamano muy impor-\ntante desde la edad del bronce hasta\nel periodo romano, asi como la exis-\ntencia de perros enanos [Figura 2].\nLa aparici\xc3\xb3n de estos morfotipos,\nposiblemente muy diferenciados, ha B\nsido un proceso paralelo al de la uti-\nlizaci\xc3\xb3n especializada de los perros.\nEl libro de caza de Gaston Phebus,\nde finales del siglo XIV, es un buen N\ntestimonio del uso que se hac\xc3\xada de\ndiferentes perros en funci\xc3\xb3n del tipo\nde caza. Recientemente, en el a\xc3\xb1o\n2010, Boyko y colaboradores han\nidentificado 51 regiones en el ge-\nnoma del perro asociadas a la va-\nriaci\xc3\xb3n fenot\xc3\xadpica de 57 caracteres\ntales como tamano corporal medio,\ndimensiones externas del cuerpo,\ndel craneo, de los dientes, forma de\nFigura 2: A. Pintura rupestre que muestra un perro de tipo\nlebrel o graioide procedente de las cuevas Tassili, en Hoggar\n(Argelia) que tienen unos 8.000 a\xc3\xb1os de antiguedad. B. Otra\npintura en la que se ve la representaci\xc3\xb3n de un perro de tipo\nmoloso en CatalHuyuk (Turqu\xc3\xada) hacia 5.850 aC.\nNumero 130 - Octubre 2014 # Canis et Felis\n23\n'},
#  {'metadata': {'filetype': 'application/pdf',
#    'filename': 'revista perros.pdf',
#    'page_number': 8},
#   'text': b'24\na GENETICA DE PERROS Y GATOS: PATOLOGIAS HEREDITARIAS\nCANIf-FELIf | Y OTROS ASPECTOS DE INTER\xc3\x89S EN LA CL\xc3\x8dNICA VETERINARIA\nlos huesos largos, etc., y encontraron que un n\xc3\xbamero muy reducido de regiones\ncromos\xc3\xb3micas explican la mayor parte de la variaci\xc3\xb3n fenot\xc3\xadpica encontrada para\nestos caracteres. Se comprob\xc3\xb3, adem\xc3\xa1s, que estos cambios gen\xc3\xb3micos son con-\nsecuencia de procesos de selecci\xc3\xb3n recientes, que se asocian a caracteres espe-\ncificos de razas [tama\xc3\xb1o corporal, tipo de capa, forma de orejas], lo que confirma\nel papel jugado por el hombre en la modificacion de la arquitectura gen\xc3\xa9tica del\nperro.\nAparicion de las razas modernas, los libros genealogicos\ny el concepto de raza pura\nEn el siglo XVIII, la cria del perro todavia se rige por principios empiricos; lo cual\nno ha impedido la emergencia de un gran numero de poblaciones diferenciadas.\nAl final del siglo XVIII, ya se conocen la mayor parte de los tipos raciales. Varias\nrazas muy similares a las actuales estan descritas en obras de naturalistas como\nBuffon en su Histoire Naturelle [1774] o Daubenteon en la Enciclopedia brit\xc3\xa1nica\ntambi\xc3\xa9n en el siglo XVIII. Los m\xc3\xa9todos de selecci\xc3\xb3n ya tratan de utilizar los ani-\nmales de mayor belleza y \xe2\x80\x9cmejores\xe2\x80\x9d, al margen de lo gue signifique mejor, para\nlas cubriciones y desaconseja usar perros que tengan defectos naturales [como la\nepilepsia] o cuyos padres los tienen. En la misma \xc3\xa9poca las experiencias de selec-\nci\xc3\xb3n de Bakewell sobre los ovinos inician una revoluci\xc3\xb3n en la producci\xc3\xb3n, aunque\nhar\xc3\xa1n falta todavia muchos decenios para que esos m\xc3\xa9todos pasen de Inglaterra\na Francia y Espana, y de la oveja al perro.\nPero hasta la primera revoluci\xc3\xb3n industrial, ya en el siglo XIX, no aparece la noci\xc3\xb3n\nmoderna de raza asociada a la de est\xc3\xa1ndar morfol\xc3\xb3gico o de comportamiento,\nque constituye la base de los primeros libros geneal\xc3\xb3gicos. Dos fen\xc3\xb3menos para-\nlelos aparecen durante el siglo XIX que modifican completamente la cr\xc3\xada canina.\nEn primer lugar, las exposiciones caninas que Se inician en 1859 en Inglaterra, y\nen 1863 en Paris, y que son el principal soporte para marcar los objetivos en la\nselecci\xc3\xb3n canina. Despu\xc3\xa9s de estos eventos, se van creando los primeros libros\ngeneal\xc3\xb3gicos. El Kennel Club ingl\xc3\xa9s se funda en 1874 y le siguen otros en otros\npaises. La formacion de los libros va de la mano con el concepto de raza pura, y las\nprincipales consecuencias sobre la evoluci\xc3\xb3n y la selecci\xc3\xb3n de las razas son que\nlos criadores van a intentar fijar las razas alrededor de un est\xc3\xa1ndar morfol\xc3\xb3gico, y\nde comportamiento. Estas razas se van a constituir en poblaciones relativamente\ncerradas, con una gestion que se coordina a nivel nacional o incluso en algunos\ncasos, Internacional. Aparece tambi\xc3\xa9n en el siglo XIX la pr\xc3\xa1ctica de la consangui-\nnidad, iniciada por los britanicos, que pretende considerar al perro no solo por si\nmismo sino tambi\xc3\xa9n por las caracteristicas de su familia y la constancia con la\nque \xc3\xa9stas se han transmitido.\nA partir de mediados del siglo XIX, con el concepto \xe2\x80\x9cfijista\xe2\x80\x9d de raza, comienza el\naislamiento reproductivo de forma mas sistematica entre los animales que se cla-\nsificaban en las diferentes razas, cuyo numero actual ronda las 400 [actualmente\nhay 358 razas caninas reconocidas por la Federaci\xc3\xb3n Cinol\xc3\xb3gica Internacional). Es\nCanis et Felis # Numero 130 - Octubre 2014\n'},
#  {'metadata': {'filetype': 'application/pdf',
#    'filename': 'revista perros.pdf',
#    'page_number': 9},
#   'text': b'Origen y diversidad de la especie canina\nevidente que el concepto de raza ha ido modificandose a lo largo del tiempo, pero\nlas consecuencias se han mantenido. Entre estas, la principal es una redistribu-\nci\xc3\xb3n de la variabilidad gen\xc3\xa9tica, parte de la cual se atribuye a diferencias entre\nrazas. El nivel de aislamiento reproductivo alcanzado entre las razas caninas ha\nLlevado a uno de los mas elevados niveles de diferenciaci\xc3\xb3n gen\xc3\xa9tica entre razas\nde todas las especies dom\xc3\xa9sticas. Recientes trabajos utilizando tanto microsat\xc3\xa9-\nlites como SNPs atribuyen a las razas entre el 27% y el 33% de la variabilidad\ngen\xc3\xa9tica total, valores muy superiores a los que se encuentran en otras especies\ndom\xc3\xa9sticas.\nComentabamos que la noci\xc3\xb3n de raza desde el siglo XIX ha sido tratada desde\nmuy diversos puntos de vista [biol\xc3\xb3gicos, culturales, sociales, administrativos],\nque pueden ser incluso antin\xc3\xb3micos. De las muchas definiciones disponibles pre-\nsentamos la de Clutton-Brock [1999]: \xe2\x80\x9cUna raza es un grupo de animales gue han\nsido seleccionados por los humanos para poseer una apariencia uniforme, heredable\nque la distingue de los demas grupos de animales de la misma especie\xe2\x80\x99. Aunque,\ncomo dec\xc3\xada K. Hammond, quien fue responsable del grupo de Recursos Gen\xc3\xa9ti-\ncos Animales de la FAO: \xe2\x80\x9cuna raza es una raza si un numero suficiente de personas\ndicen que lo es\xe2\x80\x9d. Que esto es asi, es decir, que el reconocimiento de una raza es\nun procedimiento administrativo sin que sea necesario invocar bases cientificas,\nes comprobable en numerosos ejemplos: La FCI tenia reconocidas dos razas en\nla antigua Yugoeslavia, el perro pastor yugoslavo de Charplanina y el perro pastor\ndel macizo del Karst, pero como consecuencia de la division del pais en estados\nindependientes, dos nuevas razas, morfoldgicamente similares, han sido recono-\ncidas por la FCI, el pastor de los carpatos, y el pastor de Bosnia-Herzegovina y de\nCroacia.\nEn los ultimos anos, ha habido cerca de medio millon de inscripciones de perros\nde raza pura en los libros geneal\xc3\xb3gicos. En Espana, el Libro de Or\xc3\xadgenes o LOE\nes mantenido por la Real Sociedad Canina de Espana [RSCE], que es miembro de\npleno derecho de la F\xc3\xa9d\xc3\xa9ration Cynologique Internationale [FCI] desde 1912. De las\n97.000 inscripciones realizadas en el LOE el ano 2013, la mayor parte correspon-\nden a las siguientes razas: perro de pastor aleman, yorkshire terrier, chihuahua,\nsetter ingl\xc3\xa9s, labrador retriever, bichon malt\xc3\xa9s, golden retriever, bulldog franc\xc3\xa9s,\nschnauzer miniatura, teckel, bulldog ingl\xc3\xa9s, epagneul breton, boxer, rottweiler,\nperro de agua espanol, american staffordshire terrier, mastin espanol, stafford-\nshire bull terrier, caniche y perro de pastor belga. Las cifras acumuladas de los\nUltimos cinco anos muestran una clara preferencia por las razas perro de pastor\nalem\xc3\xa1n y yorkshire terrier (40.330 y 38.812 e inscripciones respectivamente].\nLa gran mayoria de los perros inscritos en el LOE pertenecen a poblaciones rela-\ntivamente homog\xc3\xa9neas desde un punto de vista morfol\xc3\xb3gico y comportamental,\nque estan bien seguidas y seleccionadas. Esta selecci\xc3\xb3n racial permite, al favo-\nrecer tipos especializados, ampliar la diversidad entre poblaciones dentro de la\nespecie. Tambi\xc3\xa9n ha inducido seguramente una reducci\xc3\xb3n de la variabilidad gen\xc3\xa9-\ntica intra-racial y el incremento, bajo el efecto del aumento de la consanguinidad,\nde la incidencia de las afecciones hereditarias dentro de las poblaciones. Este\nNumero 130 - Octubre 2014 # Canis et Felis\n25\n'},
#  {'metadata': {'filetype': 'application/pdf',
#    'filename': 'revista perros.pdf',
#    'page_number': 10},
#   'text': b'26\na GENETICA DE PERROS Y GATOS: PATOLOGIAS HEREDITARIAS\nCANIf-FELIf | Y OTROS ASPECTOS DE INTER\xc3\x89S EN LA CL\xc3\x8dNICA VETERINARIA :\nUltimo fen\xc3\xb3meno no hace mas que acentuar la preocupaci\xc3\xb3n de los propietarios\npor el bienestar\n \ny la salud de sus perros. Los criadores y las asociaciones de razas\ndemandan, por tanto, soluciones gue les permitan luchar contra esas afecciones\ny mantener la diversidad gen\xc3\xa9tica.\nServicio de Gen\xc3\xa9tica\nFacultad de Veterinaria\nUniversidad Complutense de Madrid\n\xe2\x80\x94_ de ADN\nNA Genetica\xe2\x80\x99\nRY\\\nN\xc2\xbb\n. oo.\nojad P?\ngenetica@ucm.es oro\nUNE Et 150 9001:2008 www. ucm.es/\n \ngenetvet 4\nHs || eo 91 394 8758\nCanis et Felis # Numero 130\n \n- Octubre 2014\n'}]
